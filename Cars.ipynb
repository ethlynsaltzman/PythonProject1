# %%
import pandas as pd
import matplotlib.pyplot as plt
dfcar = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/mtcars.csv')

# %%
dfcar.shape
# Out:
# (32, 12)

# %%
dfcar.head(5)
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
dfcars = dfcar.rename(columns={'Unnamed: 0':'manufacturer'})

# %%
dfcars.head(5)
# Out:
#         manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
dfcars2 = dfcars.rename(columns={'mpg':'miles per gallon', 'cyl':'cylinders', 'hp':'horse power','wt':'weight'})

# %%
dfcars2.head(20)
# Out:
#            manufacturer  miles per gallon  cylinders   disp  horse power  \
# 0             Mazda RX4              21.0          6  160.0          110
# 1         Mazda RX4 Wag              21.0          6  160.0          110
# 2            Datsun 710              22.8          4  108.0           93
# 3        Hornet 4 Drive              21.4          6  258.0          110
# 4     Hornet Sportabout              18.7          8  360.0          175
# 5               Valiant              18.1          6  225.0          105
# 6            Duster 360              14.3          8  360.0          245
# 7             Merc 240D              24.4          4  146.7           62
# 8              Merc 230              22.8          4  140.8           95
# 9              Merc 280              19.2          6  167.6          123
# 10            Merc 280C              17.8          6  167.6          123
# 11           Merc 450SE              16.4          8  275.8          180
# ...

# %%
dfsubsetcars = dfcars2[['manufacturer','cylinders', 'miles per gallon','horse power','weight']]

# %%
dfsubsetcars.head(32)
# Out:
#            manufacturer  cylinders  miles per gallon  horse power  weight
# 0             Mazda RX4          6              21.0          110   2.620
# 1         Mazda RX4 Wag          6              21.0          110   2.875
# 2            Datsun 710          4              22.8           93   2.320
# 3        Hornet 4 Drive          6              21.4          110   3.215
# 4     Hornet Sportabout          8              18.7          175   3.440
# 5               Valiant          6              18.1          105   3.460
# 6            Duster 360          8              14.3          245   3.570
# 7             Merc 240D          4              24.4           62   3.190
# 8              Merc 230          4              22.8           95   3.150
# 9              Merc 280          6              19.2          123   3.440
# 10            Merc 280C          6              17.8          123   3.440
# 11           Merc 450SE          8              16.4          180   4.070
# ...

# %%
dfsubsetcars.describe()
# Out:
#        cylinders  miles per gallon  horse power     weight
# count  32.000000         32.000000    32.000000  32.000000
# mean    6.187500         20.090625   146.687500   3.217250
# std     1.785922          6.026948    68.562868   0.978457
# min     4.000000         10.400000    52.000000   1.513000
# 25%     4.000000         15.425000    96.500000   2.581250
# 50%     6.000000         19.200000   123.000000   3.325000
# 75%     8.000000         22.800000   180.000000   3.610000
# max     8.000000         33.900000   335.000000   5.424000

# %%
dfMerc= dfsubsetcars[dfsubsetcars['manufacturer'].str.contains('Merc')]

# %%
dfMerc.head(20)
# Out:
#    manufacturer  cylinders  miles per gallon  horse power  weight
# 7     Merc 240D          4              24.4           62    3.19
# 8      Merc 230          4              22.8           95    3.15
# 9      Merc 280          6              19.2          123    3.44
# 10    Merc 280C          6              17.8          123    3.44
# 11   Merc 450SE          8              16.4          180    4.07
# 12   Merc 450SL          8              17.3          180    3.73
# 13  Merc 450SLC          8              15.2          180    3.78

# %%
dfMerc.describe()
# Out:
#        cylinders  miles per gallon  horse power    weight
# count   7.000000          7.000000     7.000000  7.000000
# mean    6.285714         19.014286   134.714286  3.542857
# std     1.799471          3.395305    47.066316  0.333952
# min     4.000000         15.200000    62.000000  3.150000
# 25%     5.000000         16.850000   109.000000  3.315000
# 50%     6.000000         17.800000   123.000000  3.440000
# 75%     8.000000         21.000000   180.000000  3.755000
# max     8.000000         24.400000   180.000000  4.070000

# %%
dfMerc.isnull()
# Out:
#     manufacturer  cylinders  miles per gallon  horse power  weight
# 7          False      False             False        False   False
# 8          False      False             False        False   False
# 9          False      False             False        False   False
# 10         False      False             False        False   False
# 11         False      False             False        False   False
# 12         False      False             False        False   False
# 13         False      False             False        False   False

# %%
import numpy as np

# %%
dfp = {'A':[1,2,np.nan], 'B':[3,4,np.nan]}

# %%
dfpractice = pd.DataFrame(dfp)

# %%
dfpractice
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  4.0
# 2  NaN  NaN
